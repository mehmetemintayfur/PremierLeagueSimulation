# %%
import random

# %%
teams = {"Liverpool":87,"West Ham":80,"Leicester City":82,"Manchester City":88,"Watford":74,"Brentford":76,"Arsenal":82,
"Crystal Palace":77,"Man United":84,"Burnley":75,"Tottenham":84,"Everton":80,"Wolwerhampton":79,"Chelsea":85,"Norwich City":74,
"Aston Villa":78,"Newcastle United":78,"Southampton":76,"Brighton & Hove Albion":75,"Leeds United":78}
a = list(teams.values())
b = list(teams.keys())

points = {"livpuan":0,"westpuan":0,"lecpuan":0,"citypuan":0,"watpuan":0,"brepuan":0,"arspuan":0,"crypuan":0,"manupuan":0,
"burnpuan":0,"totpuan":0,"evepuan":0,"wolpuan":0,"chepuan":0,"norpuan":0,"astpuan":0,"newpuan":0,"soupuan":0,"bripuan":0,
"leepuan":0}
c = list(points.values())
d = list(points.keys())

goalsscored = {"livpuan":0,"westpuan":0,"lecpuan":0,"citypuan":0,"watpuan":0,"brepuan":0,"arspuan":0,"crypuan":0,"manupuan":0,
"burnpuan":0,"totpuan":0,"evepuan":0,"wolpuan":0,"chepuan":0,"norpuan":0,"astpuan":0,"newpuan":0,"soupuan":0,"bripuan":0,
"leepuan":0}
e = list(goalsscored.values())
f = list(goalsscored.keys())

goalsallowed = {"livpuan":0,"westpuan":0,"lecpuan":0,"citypuan":0,"watpuan":0,"brepuan":0,"arspuan":0,"crypuan":0,"manupuan":0,
"burnpuan":0,"totpuan":0,"evepuan":0,"wolpuan":0,"chepuan":0,"norpuan":0,"astpuan":0,"newpuan":0,"soupuan":0,"bripuan":0,
"leepuan":0}
g = list(goalsallowed.values())
h = list(goalsallowed.keys())


homewin = [[1,0],[3,1],[2,0],[1,0],[4,2],[2,1],[2,0],[2,1]]
draw = [[0,0],[1,1],[1,1],[2,2],[0,0],[2,2],[1,1],[3,3]]
awaywin = [[0,1],[1,3],[0,2],[0,1],[2,4],[1,2],[0,2],[1,2]]

def team1():
    for i in range(1,20):
        firstteam = random.randint(a[0]-16,a[0])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[0] += 3
            result = random.randint(0,len(homewin)-1)
            e[0] += homewin[result][0]
            g[0] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[0] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[0] += draw[result][0]
            g[0] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3
            result = random.randint(0,len(awaywin)-1)
            e[0] += awaywin[result][0]
            g[0] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
    

def team2():
   
    for i in range(2,20):
        firstteam = random.randint(a[1]-19,a[1])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[1] += 3
            result = random.randint(0,len(homewin)-1)
            e[1] += homewin[result][0]
            g[1] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[1] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[1] += draw[result][0]
            g[1] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3
            result = random.randint(0,len(awaywin)-1)
            e[1] += awaywin[result][0]
            g[1] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team3():
   
    for i in range(3,20):
        firstteam = random.randint(a[2]-18,a[2])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[2] += 3
            result = random.randint(0,len(homewin)-1)
            e[2] += homewin[result][0]
            g[2] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[2] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[2] += draw[result][0]
            g[2] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3      
            result = random.randint(0,len(awaywin)-1)
            e[2] += awaywin[result][0]
            g[2] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
                
def team4():
   
    for i in range(4,20):
        firstteam = random.randint(a[3]-16,a[3])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[3] += 3
            result = random.randint(0,len(homewin)-1)
            e[3] += homewin[result][0]
            g[3] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[3] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[3] += draw[result][0]
            g[3] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3
            result = random.randint(0,len(awaywin)-1)
            e[3] += awaywin[result][0]
            g[3] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team5():
   
    for i in range(5,20):
        firstteam = random.randint(a[4]-20,a[4])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[4] += 3
            result = random.randint(0,len(homewin)-1)
            e[4] += homewin[result][0]
            g[4] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[4] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[4] += draw[result][0]
            g[4] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3          
            result = random.randint(0,len(awaywin)-1)
            e[4] += awaywin[result][0]
            g[4] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
        

def team6():
   
    for i in range(6,20):
        firstteam = random.randint(a[5]-19,a[5])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[5] += 3
            result = random.randint(0,len(homewin)-1)
            e[5] += homewin[result][0]
            g[5] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[5] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[5] += draw[result][0]
            g[5] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[5] += awaywin[result][0]
            g[5] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team7():
   
    for i in range(7,20):
        firstteam = random.randint(a[6]-17,a[6])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[6] += 3
            result = random.randint(0,len(homewin)-1)
            e[6] += homewin[result][0]
            g[6] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[6] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[6] += draw[result][0]
            g[6] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[6] += awaywin[result][0]
            g[6] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team8():
   
    for i in range(8,20):
        firstteam = random.randint(a[7]-18,a[7])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[7] += 3
            result = random.randint(0,len(homewin)-1)
            e[7] += homewin[result][0]
            g[7] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[7] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[7] += draw[result][0]
            g[7] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[7] += awaywin[result][0]
            g[7] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team9():
   
    for i in range(9,20):
        firstteam = random.randint(a[8]-17,a[8])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[8] += 3
            result = random.randint(0,len(homewin)-1)
            e[8] += homewin[result][0]
            g[8] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[8] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[8] += draw[result][0]
            g[8] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[8] += awaywin[result][0]
            g[8] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team10():
   
    for i in range(10,20):
        firstteam = random.randint(a[9]-20,a[9])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[9] += 3
            result = random.randint(0,len(homewin)-1)
            e[9] += homewin[result][0]
            g[9] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[9] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[9] += draw[result][0]
            g[9] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[9] += awaywin[result][0]
            g[9] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

            
def team11():
   
    for i in range(11,20):
        firstteam = random.randint(a[10]-17,a[10])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[10] += 3
            result = random.randint(0,len(homewin)-1)
            e[10] += homewin[result][0]
            g[10] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[10] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[10] += draw[result][0]
            g[10] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[10] += awaywin[result][0]
            g[10] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
            
def team12():
   
    for i in range(12,20):
        firstteam = random.randint(a[11]-18,a[11])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[11] += 3
            result = random.randint(0,len(homewin)-1)
            e[11] += homewin[result][0]
            g[11] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[11] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[11] += draw[result][0]
            g[11] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[11] += awaywin[result][0]
            g[11] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team13():
   
    for i in range(13,20):
        firstteam = random.randint(a[12]-19,a[12])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[12] += 3
            result = random.randint(0,len(homewin)-1)
            e[12] += homewin[result][0]
            g[12] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[12] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[12] += draw[result][0]
            g[12] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[12] += awaywin[result][0]
            g[12] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

            
def team14():
   
    for i in range(14,20):
        firstteam = random.randint(a[13]-17,a[13])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[13] += 3
            result = random.randint(0,len(homewin)-1)
            e[13] += homewin[result][0]
            g[13] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[13] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[13] += draw[result][0]
            g[13] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[13] += awaywin[result][0]
            g[13] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
            

def team15():
   
    for i in range(15,20):
        firstteam = random.randint(a[14]-20,a[14])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[14] += 3
            result = random.randint(0,len(homewin)-1)
            e[14] += homewin[result][0]
            g[14] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[14] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[14] += draw[result][0]
            g[14] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[14] += awaywin[result][0]
            g[14] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]            
            
            
def team16():
   
    for i in range(16,20):
        firstteam = random.randint(a[15]-19,a[15])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[15] += 3
            result = random.randint(0,len(homewin)-1)
            e[15] += homewin[result][0]
            g[15] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[15] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[15] += draw[result][0]
            g[15] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[15] += awaywin[result][0]
            g[15] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]   
            
def team17():
   
    for i in range(17,20):
        firstteam = random.randint(a[16]-17,a[16])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[16] += 3
            result = random.randint(0,len(homewin)-1)
            e[16] += homewin[result][0]
            g[16] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[16] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[16] += draw[result][0]
            g[16] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[16] += awaywin[result][0]
            g[16] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]   
            
def team18():
   
    for i in range(18,20):
        firstteam = random.randint(a[17]-18,a[17])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[17] += 3
            result = random.randint(0,len(homewin)-1)
            e[17] += homewin[result][0]
            g[17] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[17] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[17] += draw[result][0]
            g[17] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[17] += awaywin[result][0]
            g[17] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]   
            
def team19():
   
    firstteam = random.randint(a[18]-20,a[18])    
    secondteam = random.randint(a[19]-21,a[19])
    if firstteam > secondteam:
        c[18] += 3
        result = random.randint(0,len(homewin)-1)
        e[18] += homewin[result][0]
        g[18] += homewin[result][1]
        e[19] += homewin[result][1]
        g[19] += homewin[result][0]
    elif firstteam == secondteam:
        c[18] += 1
        c[19] += 1
        result = random.randint(0,len(draw)-1)
        e[18] += draw[result][0]
        g[18] += draw[result][1]
        e[19] += draw[result][1]
        g[19] += draw[result][0]
    else:
        c[19] += 3 
        result = random.randint(0,len(awaywin)-1)
        e[18] += awaywin[result][0]
        g[18] += awaywin[result][1]
        e[19] += awaywin[result][1]
        g[19] += awaywin[result][0]

## change
         

def team20():
   
    for i in range(18,-1,-1):
        firstteam = random.randint(a[19]-19,a[19])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[19] += 3
            result = random.randint(0,len(homewin)-1)
            e[19] += homewin[result][0]
            g[19] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[19] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[19] += draw[result][0]
            g[19] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[19] += awaywin[result][0]
            g[19] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]    

def team192():
   
    for i in range(17,-1,-1):
        firstteam = random.randint(a[18]-20,a[18])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[18] += 3
            result = random.randint(0,len(homewin)-1)
            e[18] += homewin[result][0]
            g[18] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[18] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[18] += draw[result][0]
            g[18] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[18] += awaywin[result][0]
            g[18] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]  

def team182():
   
    for i in range(16,-1,-1):
        firstteam = random.randint(a[17]-18,a[17])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[17] += 3
            result = random.randint(0,len(homewin)-1)
            e[17] += homewin[result][0]
            g[17] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[17] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[17] += draw[result][0]
            g[17] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[17] += awaywin[result][0]
            g[17] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

    
def team172():
   
    for i in range(15,-1,-1):
        firstteam = random.randint(a[16]-17,a[16])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[16] += 3
            result = random.randint(0,len(homewin)-1)
            e[16] += homewin[result][0]
            g[16] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[16] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[16] += draw[result][0]
            g[16] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[16] += awaywin[result][0]
            g[16] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
    
def team162():
   
    for i in range(14,-1,-1):
        firstteam = random.randint(a[15]-19,a[15])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[15] += 3
            result = random.randint(0,len(homewin)-1)
            e[15] += homewin[result][0]
            g[15] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[15] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[15] += draw[result][0]
            g[15] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[15] += awaywin[result][0]
            g[15] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
    
def team152():
   
    for i in range(13,-1,-1):
        firstteam = random.randint(a[14]-20,a[14])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[14] += 3
            result = random.randint(0,len(homewin)-1)
            e[14] += homewin[result][0]
            g[14] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[14] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[14] += draw[result][0]
            g[14] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[14] += awaywin[result][0]
            g[14] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
    
def team142():
   
    for i in range(12,-1,-1):
        firstteam = random.randint(a[13]-17,a[13])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[13] += 3
            result = random.randint(0,len(homewin)-1)
            e[13] += homewin[result][0]
            g[13] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[13] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[13] += draw[result][0]
            g[13] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[14] += awaywin[result][0]
            g[14] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
    

            
def team132():
   
    for i in range(11,-1,-1):
        firstteam = random.randint(a[12]-19,a[12])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[12] += 3
            result = random.randint(0,len(homewin)-1)
            e[12] += homewin[result][0]
            g[12] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[12] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[12] += draw[result][0]
            g[12] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[12] += awaywin[result][0]
            g[12] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
            
def team122():
   
    for i in range(10,-1,-1):
        firstteam = random.randint(a[11]-18,a[11])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[11] += 3
            result = random.randint(0,len(homewin)-1)
            e[11] += homewin[result][0]
            g[11] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[11] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[11] += draw[result][0]
            g[11] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[11] += awaywin[result][0]
            g[11] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]           
            
            
def team112():
   
    for i in range(9,-1,-1):
        firstteam = random.randint(a[10]-17,a[10])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[10] += 3
            result = random.randint(0,len(homewin)-1)
            e[10] += homewin[result][0]
            g[10] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[10] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[10] += draw[result][0]
            g[10] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[10] += awaywin[result][0]
            g[10] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
           
    

def team102():
   
    for i in range(8,-1,-1):
        firstteam = random.randint(a[9]-20,a[9])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[9] += 3
            result = random.randint(0,len(homewin)-1)
            e[9] += homewin[result][0]
            g[9] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[9] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[9] += draw[result][0]
            g[9] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[9] += awaywin[result][0]
            g[9] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
        
        
def team92():
   
    for i in range(7,-1,-1):
        firstteam = random.randint(a[8]-17,a[8])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[8] += 3
            result = random.randint(0,len(homewin)-1)
            e[8] += homewin[result][0]
            g[8] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[8] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[8] += draw[result][0]
            g[8] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[8] += awaywin[result][0]
            g[8] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]      

def team82():
   
    for i in range(6,-1,-1):
        firstteam = random.randint(a[7]-18,a[7])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[7] += 3
            result = random.randint(0,len(homewin)-1)
            e[7] += homewin[result][0]
            g[7] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[7] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[7] += draw[result][0]
            g[7] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[7] += awaywin[result][0]
            g[7] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
            
def team72():
   
    for i in range(5,-1,-1):
        firstteam = random.randint(a[6]-17,a[6])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[6] += 3
            result = random.randint(0,len(homewin)-1)
            e[6] += homewin[result][0]
            g[6] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[6] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[6] += draw[result][0]
            g[6] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[6] += awaywin[result][0]
            g[6] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team62():
   
    for i in range(4,-1,-1):
        firstteam = random.randint(a[5]-19,a[5])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[5] += 3
            result = random.randint(0,len(homewin)-1)
            e[5] += homewin[result][0]
            g[5] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[5] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[5] += draw[result][0]
            g[5] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[5] += awaywin[result][0]
            g[5] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]
            

def team52():
   
    for i in range(3,-1,-1):
        firstteam = random.randint(a[4]-20,a[4])    
        secondteam = random.randint(a[i]-20,a[i])
        if firstteam > secondteam:
            c[4] += 3
            result = random.randint(0,len(homewin)-1)
            e[4] += homewin[result][0]
            g[4] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[4] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[4] += draw[result][0]
            g[4] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[4] += awaywin[result][0]
            g[4] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

def team42():
   
    for i in range(2,-1,-1):
        firstteam = random.randint(a[3]-20,a[3])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[3] += 3
            result = random.randint(0,len(homewin)-1)
            e[3] += homewin[result][0]
            g[3] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[3] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[3] += draw[result][0]
            g[3] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[3] += awaywin[result][0]
            g[3] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]


def team32():
   
    for i in range(1,-1,-1):
        firstteam = random.randint(a[2]-18,a[2])    
        secondteam = random.randint(a[i]-21,a[i])
        if firstteam > secondteam:
            c[2] += 3
            result = random.randint(0,len(homewin)-1)
            e[2] += homewin[result][0]
            g[2] += homewin[result][1]
            e[i] += homewin[result][1]
            g[i] += homewin[result][0]
        elif firstteam == secondteam:
            c[2] += 1
            c[i] += 1
            result = random.randint(0,len(draw)-1)
            e[2] += draw[result][0]
            g[2] += draw[result][1]
            e[i] += draw[result][1]
            g[i] += draw[result][0]
        else:
            c[i] += 3 
            result = random.randint(0,len(awaywin)-1)
            e[2] += awaywin[result][0]
            g[2] += awaywin[result][1]
            e[i] += awaywin[result][1]
            g[i] += awaywin[result][0]

            
def team22():
   
    firstteam = random.randint(a[1]-19,a[1])    
    secondteam = random.randint(a[0]-21,a[0])
    if firstteam > secondteam:
        c[1] += 3
        result = random.randint(0,len(homewin)-1)
        e[1] += homewin[result][0]
        g[1] += homewin[result][1]
        e[0] += homewin[result][1]
        g[0] += homewin[result][0]
    elif firstteam == secondteam:
        c[1] += 1
        c[0] += 1
        result = random.randint(0,len(draw)-1)
        e[1] += draw[result][0]
        g[1] += draw[result][1]
        e[0] += draw[result][1]
        g[0] += draw[result][0]
    else:
        c[0] += 3 
        result = random.randint(0,len(awaywin)-1)
        e[1] += awaywin[result][0]
        g[1] += awaywin[result][1]
        e[0] += awaywin[result][1]
        g[0] += awaywin[result][0]

            
    
team1()
team2()
team3()
team4()
team5()
team6()
team7()
team8()
team9()
team10()
team11()
team12()
team13()
team14()
team15()
team16()
team17()
team18()
team19()
team20()
team192()
team182()
team172()
team162()
team152()
team142()
team132()
team122()
team112()
team102()
team92()
team82()
team72()
team62()
team52()
team42()
team32()
team22()


lastpoints = dict(zip(b,c))

# %%
sort_orders = sorted(lastpoints.items(), key=lambda x: x[1], reverse=True)

for i in sort_orders:
    print(i[0], i[1])
# Out:
# Manchester City 96
# Liverpool 94
# Tottenham 87
# Man United 79
# Leicester City 76
# Arsenal 73
# Chelsea 70
# West Ham 54
# Everton 54
# Wolwerhampton 54
# Southampton 51
# Crystal Palace 50
# Newcastle United 45
# Leeds United 43
# Burnley 40
# Brentford 39
# Brighton & Hove Albion 34
# Aston Villa 33
# Watford 31
# Norwich City 23
